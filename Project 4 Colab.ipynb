# %%
# Import required libraries
import numpy as np
import os
import pandas as pd
import hvplot.pandas
from pathlib import Path
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %% [markdown]
# # price is the y I think
# # x is the other columns ...
# # what columa do we drop ...Module 21 activiy 7 day 2 also activity 04

# %%
# load file
file_path = "C:\\Users\\linet\\OneDrive\\Desktop\\Project 4\\Home-Sales-Prediction\\Resources\\original_extracted_df.csv"
home = pd.read_csv(file_path)

# Print the shape of the DataFrame
print(home2.shape)

# Print the first few rows of the DataFrame
home.head()

# %%
# Drop rows with NaN values
home_cleaned = home.dropna()

# Print the shape of the cleaned DataFrame
print(home_cleaned.shape)

# Print the first few rows of the cleaned DataFrame
home_cleaned.head()

# %%
# Get data types of each column
data_types = home_cleaned.dtypes
data_types

# %%
# Get unique states
unique_states = home_cleaned['State'].unique()
unique_states

# %%
# Define numerical and categorical columns
numerical_cols = ['Zipcode', 'Latitude', 'Longitude', 'Bedroom', 'Bathroom', 'Area', 'PPSq', 'LotArea', 'ConvertedLot', 'MarketEstimate', 'RentEstimate', 'Price']
categorical_cols = ['State', 'City', 'Street', 'LotUnit']

# %%
# seperate the features, X, from the target variable, y
y = home_cleaned
X = home_cleaned.drop(columns='y')

# %%
# Preview the first five enteries for the target variable
y[:5]

# %%
# Encode the categorical variables from the features data using get_dummies.
# Encode the categorical variables using get_dummies
X = pd.get_dummies(X)
# Review the features data
X.head()

# %%
Separate the data into training and testing subsets.
# Split the dataset using train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
y_test.value_counts()

# %%
# from pyspark.sql import SparkSession

# # Initialize SparkSession
# spark = SparkSession.builder \
#     .appName("HomeDFToSQL") \
#     .getOrCreate()

# %%
# # Create a temporary view for the DataFrame
# home.createOrReplaceTempView("home_cleaned")

# %%
# spark.sql("CREATE TABLE IF NOT EXISTS table_name AS SELECT * FROM home_view")

# %%
# # Stop SparkSession (after you're done with Spark)
# spark.stop()

# %%
# file_path = "C:\\Users\\linet\\OneDrive\\Desktop\\Project 4\\Home-Sales-Prediction\\Resources\\na_dropped_df.csv"
# home2 = pd.read_csv(file_path)
# print(home2.shape)
# home2.head()

# %%
# file_path = "C:\\Users\\linet\\OneDrive\\Desktop\\Project 4\\Home-Sales-Prediction\\Resources\\cleaned_df.csv"
# home1 = pd.read_csv(file_path)
# print(home1.shape)
# home1.head()

# %% [markdown]
# HOME VALUES FORECASTS
# Zillow Home Value Forecast (ZHVF): A month-ahead, quarter-ahead and year-ahead forecast of the Zillow Home Value Index (ZHVI). ZHVF is created using the all homes, mid-tier cut of ZHVI and is available both raw and smoothed, seasonally adjusted.
# "C:\Users\linet\OneDrive\Desktop\Project 4\Metro_zhvf_growth_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv"

# %%
# # Load data
# file_path = file_path = "C:\\Users\\linet\\OneDrive\\Desktop\\Project 4\\Metro_zhvf_growth_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv"
# home_values_forecasts = pd.read_csv(file_path)
# print(home_values_forecasts.shape)
# home_values_forecasts.head()

# %% [markdown]
# HOME VALUES
#
# Zillow Home Value Index (ZHVI): A measure of the typical home value and market changes across a given region and housing type.
# It reflects the typical value for homes in the 35th to 65th percentile range.
# Available as a smoothed, seasonally adjusted measure and as a raw measure.
# "C:\Users\linet\OneDrive\Desktop\Project 4\Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv"

# %%
# # Load data
# file_path = 'C:\\Users\\linet\\OneDrive\\Desktop\\Project 4\\Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv'
# home_values = pd.read_csv(file_path)
# print(home_values.shape)
# home_values.head()

# %% [markdown]
# MARKET HEAT INDEX
# The market heat index is a time series dataset that aims to capture the balance of for-sale supply and demand in a given market.
# A higher number means the market is more tilted in favor of sellers. It relies on a combination of engagement and listing performance inputs
# to provide insights into current market dynamics. It is calculated for single-family and condo homes.
#
# "C:\Users\linet\OneDrive\Desktop\Project 4\Metro_market_temp_index_uc_sfrcondo_month.csv"

# %%
# # Load data
#  file_path = "C:\\Users\\linet\\OneDrive\\Desktop\\Project 4\\Metro_market_temp_index_uc_sfrcondo_month.csv"
# market_heat_index = pd.read_csv(file_path)
# print(market_heat_index.shape)
# market_heat_index.head()

# %% [markdown]
# SALES
# The Sales Count Nowcast is the estimated number of unique properties that sold during the month after accounting for the
# latency between when sales occur and when they are reported. Available only for the raw cut of all homes.
# Sale Price (median/mean): The price at which homes across various geographies were sold.
# Total Transaction Value: The total dollar value of all homes sold in a given period (mean sale price x sales count)
# Sale-to-List Ratio (mean/median): Ratio of sale vs. final list price.
# Percent of Sales Below/Above List: Share of sales where sale price below/above the final list price; excludes homes sold for exactly the list price.
# "C:\Users\linet\OneDrive\Desktop\Project 4\Metro_sales_count_now_uc_sfrcondo_month.csv"

# %%
# # Load data
# file_path = "C:\\Users\\linet\\OneDrive\\Desktop\\Project 4\\Metro_sales_count_now_uc_sfrcondo_month.csv"
# sales = pd.read_csv(file_path)
# print(sales.shape)
# sales.head()
